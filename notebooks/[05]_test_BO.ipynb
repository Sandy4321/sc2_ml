# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from glob import glob
import sys
sys.path.append('../src/')
from buildings import BuildOrders
datasetfolder = "i:/StarCraft_BO/replayActionList/*"
datasetfiles = glob(datasetfolder)

# %%
terran = BuildOrders('Terran', datasetfiles)

# %%
df_terran = terran.build_orders()

# %%
df_terran.plot(figsize=(18,5), ylim=(0,0.25), colormap='tab20')
plt.show()

# %%
zerg = BuildOrders('Zerg', datasetfiles)

# %%
df_zerg = zerg.build_orders()

# %%
df_zerg.plot(figsize=(18,5), ylim=(0,0.25), colormap='tab20')
plt.show()

# %%
protoss = BuildOrders('Protoss', datasetfiles)

# %%
df_protoss = protoss.build_orders()

# %%
df_protoss.plot(figsize=(18,5), ylim=(0,0.25), colormap='tab20')
plt.show()
