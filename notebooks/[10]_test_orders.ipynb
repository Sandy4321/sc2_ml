# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
from collections import deque

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from glob import glob
import sys
sys.path.append('../src/')
from parsing import Parse
from training import TrainingOrders
datasetfolder = "/home/michael/Documents/SCreplay/replayActionList/*"
datasetfiles = glob(datasetfolder)

# %%
from building import terran_buildings, protoss_buildings, zerg_buildings
from training import terran_units, protoss_units, zerg_units

# %%
from BO import Orders

# %%
o = Orders('TvP')

# %%
df = o.winning_BO(datasetfiles[:2000], eps=0.8, min_sample=5, max_frames=40000, depth=10)

# %%
df[df.columns.intersection(terran_buildings)].plot(figsize=(15,5))
plt.show()

# %%
df[df.columns.intersection(terran_units)].plot(figsize=(15,5))
plt.show()

# %%
TvZ = Orders('TvZ')

# %%
df_TvZ = TvZ.winning_BO(datasetfiles[:2000], eps=0.8, min_sample=5, max_frames=40000, depth=10)

# %%
df_TvZ[df_TvZ.columns.intersection(terran_buildings)].plot(figsize=(15,5))
plt.show()

# %%
df_TvZ[df_TvZ.columns.intersection(terran_units)].plot(figsize=(15,5))
plt.show()

# %%
TvT = Orders('TvT')

# %%
df_TvT = TvT.winning_BO(datasetfiles[:2000], eps=0.8, min_sample=5, max_frames=40000, depth=10)

# %%
df_TvT[df_TvT.columns.intersection(terran_buildings)].plot(figsize=(15,5))
plt.show()

# %%
df_TvT[df_TvT.columns.intersection(terran_units)].plot(figsize=(15,5))
plt.show()
