# %%
from glob import glob

# %%
replays = glob('i:/StarCraft II/3.16.1-Pack_2/3.16.1-Pack_2/replays/*')

# %%
replays[0]
# Out:
# 'i:/StarCraft II/3.16.1-Pack_2/3.16.1-Pack_2/replays\\000034772b83aed5732879a679487bbd496304b1490313ae9daaef3117391707.SC2Replay'

# %%
import sc2reader

# %%
r = sc2reader.load_replay(replays[0], load_level=4)

# %%
for i in r.events:
    print(i)
# Out:
# 00.00	Player 1 - (Zerg) UserOptionsEvent
# 00.00	Player 2 - (Zerg) UserOptionsEvent
# 00.00	Player 2 - (Zerg) CameraEvent at (127.25, 27.5078125)
# 00.00	Player 1 - (Zerg) CameraEvent at (24.75, 137.0078125)
# 00.01	Player 1 - (Zerg) SelectionEvent['Egg [33C0001]', 'Egg [3400001]', 'Egg [3440001]']
# 00.01	Player 2 - (Zerg) SelectionEvent['Lair [37C0001]']
# 00.01	Player 1 - (Zerg) Ability (1820) - MorphDrone
# 00.01	Player 2 - (Zerg) SelectionEvent['Egg [3800001]', 'Egg [3840001]', 'Egg [3880001]']
# 00.01	Player 2 - (Zerg) Ability (1820) - MorphDrone
# 00.01	Player 1 - (Zerg) SelectionEvent['Drone [35C0001]', 'Drone [3640001]', 'Drone [36C0001]', 'Drone [3740001]']
# 00.01	Player 1 - (Zerg) Right Click; Location: (19.80615234375, 136.875244140625, 49136)
# 00.01	Player 2 - (Zerg) SelectionEvent['Egg [3800001]']
# 00.01	Player 2 - (Zerg) SelectionEvent['Drone [3B40001]']
# ...
